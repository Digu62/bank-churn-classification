# %% [markdown]
# # Importing libs

# %%
#Imports
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Downloading database

# %%
#Lista todos os datasets do kaggle
# !kaggle datasets list
# Out:
# ref                                                         title                                                    size  lastUpdated                 downloadCount  voteCount  usabilityRating
# ----------------------------------------------------------  -------------------------------------------------  ----------  --------------------------  -------------  ---------  ---------------
# adilshamim8/student-depression-dataset                      Student Depression Dataset                             467020  2025-03-13 03:12:30.423000          18230        287  1.0
# khushikyad001/covid-19-global-dataset                       Covid-19 Global Dataset                                482555  2025-04-12 18:25:15.140000            930         22  1.0
# shantanugarg274/sales-dataset                               Sales Dataset                                           24621  2025-03-22 16:21:02.010000           2358         38  1.0
# ...

# %%
#Baixa o conjunto de dados
if not os.path.exists("dataset"):
    print(f"Baixando conjunto de dados...")
    # !kaggle competitions download -c playground-series-s4e1 -p dataset

    import zipfile
    import os

    zip_path = "dataset/playground-series-s4e1.zip"

    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall("dataset")

    #Apagaga o arquivo .zip
    os.remove(zip_path)

# %% [markdown]
# # Exploratory Data Analysis  (EDA)

# %% [markdown]
# ## Reading data

# %%
train_path = "dataset/train.csv"
sample_path = "dataset/sample_submission.csv"
test_path = "dataset/test.csv"

train_data = pd.read_csv(train_path)
test_data = pd.read_csv(test_path)
sample_data = pd.read_csv(sample_path)

# %% [markdown]
# ## Visualyzing data

# %% [markdown]
# ### Train data

# %%
train_data
# Out:
#             id  CustomerId         Surname  CreditScore Geography  Gender  \
# 0            0    15674932  Okwudilichukwu          668    France    Male
# 1            1    15749177   Okwudiliolisa          627    France    Male
# 2            2    15694510           Hsueh          678    France    Male
# 3            3    15741417             Kao          581    France    Male
# 4            4    15766172       Chiemenam          716     Spain    Male
# ...        ...         ...             ...          ...       ...     ...
# 165029  165029    15667085            Meng          667     Spain  Female
# 165030  165030    15665521       Okechukwu          792    France    Male
# 165031  165031    15664752            Hsia          565    France    Male
# 165032  165032    15689614          Hsiung          554     Spain  Female
# 165033  165033    15732798         Ulyanov          850    France    Male
#
#          Age  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165034 entries, 0 to 165033
# Data columns (total 14 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   id               165034 non-null  int64
#  1   CustomerId       165034 non-null  int64
#  2   Surname          165034 non-null  object
#  3   CreditScore      165034 non-null  int64
#  4   Geography        165034 non-null  object
#  5   Gender           165034 non-null  object
#  6   Age              165034 non-null  float64
#  7   Tenure           165034 non-null  int64
#  8   Balance          165034 non-null  float64
#  9   NumOfProducts    165034 non-null  int64
#  10  HasCrCard        165034 non-null  float64
#  11  IsActiveMember   165034 non-null  float64
#  12  EstimatedSalary  165034 non-null  float64
#  13  Exited           165034 non-null  int64
# dtypes: float64(5), int64(6), object(3)
# memory usage: 17.6+ MB

# %%
train_data.describe()
# Out:
#                 id    CustomerId    CreditScore            Age         Tenure  \
# count  165034.0000  1.650340e+05  165034.000000  165034.000000  165034.000000
# mean    82516.5000  1.569201e+07     656.454373      38.125888       5.020353
# std     47641.3565  7.139782e+04      80.103340       8.867205       2.806159
# min         0.0000  1.556570e+07     350.000000      18.000000       0.000000
# 25%     41258.2500  1.563314e+07     597.000000      32.000000       3.000000
# 50%     82516.5000  1.569017e+07     659.000000      37.000000       5.000000
# 75%    123774.7500  1.575682e+07     710.000000      42.000000       7.000000
# max    165033.0000  1.581569e+07     850.000000      92.000000      10.000000
#
#              Balance  NumOfProducts      HasCrCard  IsActiveMember  \
# count  165034.000000  165034.000000  165034.000000   165034.000000
# mean    55478.086689       1.554455       0.753954        0.497770
# ...

# %%
import webbrowser
from ydata_profiling import ProfileReport

profile = ProfileReport(train_data, title="Train data report")

eda_dir = "data_analysis"
if not os.path.exists(eda_dir):
    os.makedirs(eda_dir)
    
# Salvando o relatório em um arquivo HTML
report_path = f"./{eda_dir}/train_data_report.html"
profile.to_file(report_path)

# Abrindo automaticamente no navegador
webbrowser.open(report_path)
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# True

# %%
#Análise univariada
    #Verificar balanceamento de classes
    #Plotar salario estimado
    #Plotar membros ativos
    #Plotar usuários com crCard
    #Plotar quantidade de produtos
    #Plotar idade dos usuários
    #Plorar score dos usuários
    #Plotar saldo dos usuários (balance)
    # Plotar tempo dos usuários (Tenure)
#Análise bivariada
    #Exited Vs Salary Estimation
    #Exited Vs Active Members
    #Exited Vs Credit Card
    #Exited Vs Number of Products
    #Exited Vs Age
    #Exited Vs Score
    #Exited Vs Balance
    #Exited Vs Tenure

# %% [markdown]
# ### Test Data

# %%
test_data

# %%
test_data.info()

# %% [markdown]
# ### Sample data

# %%
sample_data

# %% [markdown]
# ## Data Preprocessing

# %%
#Remover outliers
#Tratar dados faltantes
#Normalizar/padronizar os dados
